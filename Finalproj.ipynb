# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.106.132.33

# %%
! streamlit run DV_Project.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.132.33:8501
#
# npx: installed 22 in 5.584s
# your url is: https://clever-memes-care.loca.lt
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 2024-06-18 07:52:43.940 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/DV_Project.py", line 551, in <module>
#     main()
#   File "/content/DV_Project.py", line 333, in main
# ...

# %%
pip install selenium

# %%
pip install webdriver_manager

# %%
from selenium import webdriver

driver_path = '/path/to/chromedriver.exe'  # Specify the correct path to chromedriver
driver = webdriver.Chrome(driver_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-0be388b6e50e> in <cell line: 4>()
#       2
#       3 driver_path = '/path/to/chromedriver.exe'  # Specify the correct path to chromedriver
# ----> 4 driver = webdriver.Chrome(driver_path)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      48
#      49         finder = DriverFinder(self.service, options)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# Specify the path to the ChromeDriver executable
chrome_driver_path = '/content/chromedriver.exe'  # Replace with the actual path

# Specify the path to the Chrome binary if it's not in the default location
chrome_binary_path = '/path/to/chrome'  # Replace with the actual path if needed

# Set up Chrome options
chrome_options = Options()
chrome_options.binary_location = chrome_binary_path
chrome_options.add_argument('--headless')  # Run Chrome in headless mode
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Set up the Chrome service
service = ChromeService(executable_path=chrome_driver_path)

# Initialize the Selenium webdriver
driver = webdriver.Chrome(service=service, options=chrome_options)

# URL of the website to scrape
url = "https://homebase.map-dynamics.com/cmpx2024/marketplace/"

# Load the website
driver.get(url)

# Wait for the page to load
time.sleep(5)  # You can adjust the sleep time based on your internet connection

# Get the HTML content
html = driver.page_source

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find all company cards on the page
company_cards = soup.find_all('div', class_='company-card')

# Create an empty list to store the extracted data
companies = []

# Loop through each company card
for card in company_cards:
    company = {}

    # Extract company name
    company_name = card.find('h3', class_='company-name').text.strip()
    company['name'] = company_name

    # Extract website
    website = card.find('a', class_='website')
    if website:
        company['website'] = website['href']
    else:
        company['website'] = 'Not available'

    # Extract phone number
    phone = card.find('span', class_='phone')
    if phone:
        company['phone'] = phone.text.strip()
    else:
        company['phone'] = 'Not available'

    # Extract address
    address = card.find('span', class_='address')
    if address:
        company['address'] = address.text.strip()
    else:
        company['address'] = 'Not available'

    # Extract social media links
    social_media = card.find_all('a', class_='social-media')
    company['facebook'] = 'Not available'
    company['twitter'] = 'Not available'
    company['instagram'] = 'Not available'
    for link in social_media:
        if 'facebook' in link['href']:
            company['facebook'] = link['href']
        elif 'twitter' in link['href']:
            company['twitter'] = link['href']
        elif 'instagram' in link['href']:
            company['instagram'] = link['href']

    # Add company to the list
    companies.append(company)

# Print the extracted data
for company in companies:
    print(f"Company: {company['name']}")
    print(f"Website: {company['website']}")
    print(f"Phone: {company['phone']}")
    print(f"Address: {company['address']}")
    print(f"Facebook: {company['facebook']}")
    print(f"Twitter: {company['twitter']}")
    print(f"Instagram: {company['instagram']}")
    print("---")

# Close the Selenium webdriver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/common/service.py in _start_process(self, path)
#     207
# --> 208             self.process = subprocess.Popen(
#     209                 cmd,
#
# /usr/lib/python3.10/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     970
# --> 971             self._execute_child(args, executable, preexec_fn, close_fds,
#     972                                 pass_fds, cwd, env,
#
# ...

# %%
pip install requests_html
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from requests_html import AsyncHTMLSession
from bs4 import BeautifulSoup

# ... (rest of the script remains the same)

# %%
import asyncio
from requests_html import AsyncHTMLSession
from bs4 import BeautifulSoup

# URL of the website to scrape
url = "https://homebase.map-dynamics.com/cmpx2024/marketplace/"

async def main():
    # Create an AsyncHTMLSession
    session = AsyncHTMLSession()

    # Send a request to the website and get the HTML content
    response = await session.get(url)

    # Render the JavaScript content
    await response.html.arender(sleep=5)  # You can adjust the sleep time based on your internet connection

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.html.html, 'html.parser')

    # Find all company cards on the page
    company_cards = soup.find_all('div', class_='company-card')

    # Create an empty list to store the extracted data
    companies = []

    # Loop through each company card
    for card in company_cards:
        company = {}

        # Extract company name
        company_name = card.find('h3', class_='company-name').text.strip()
        company['name'] = company_name

        # Extract website
        website = card.find('a', class_='website')
        if website:
            company['website'] = website['href']
        else:
            company['website'] = 'Not available'

        # Extract phone number
        phone = card.find('span', class_='phone')
        if phone:
            company['phone'] = phone.text.strip()
        else:
            company['phone'] = 'Not available'

        # Extract address
        address = card.find('span', class_='address')
        if address:
            company['address'] = address.text.strip()
        else:
            company['address'] = 'Not available'

        # Extract social media links
        social_media = card.find_all('a', class_='social-media')
        company['facebook'] = 'Not available'
        company['twitter'] = 'Not available'
        company['instagram'] = 'Not available'
        for link in social_media:
            if 'facebook' in link['href']:
                company['facebook'] = link['href']
            elif 'twitter' in link['href']:
                company['twitter'] = link['href']
            elif 'instagram' in link['href']:
                company['instagram'] = link['href']

        # Add company to the list
        companies.append(company)

    # Print the extracted data
    for company in companies:
        print(f"Company: {company['name']}")
        print(f"Website: {company['website']}")
        print(f"Phone: {company['phone']}")
        print(f"Address: {company['address']}")
        print(f"Facebook: {company['facebook']}")
        print(f"Twitter: {company['twitter']}")
        print(f"Instagram: {company['instagram']}")
        print("---")

    # Close the session
    await session.close()

# Run the main function
asyncio.run(main())
# Out:
# [INFO] Starting Chromium download.
# INFO:pyppeteer.chromium_downloader:Starting Chromium download.
# 100%|██████████| 183M/183M [00:07<00:00, 24.6Mb/s]
# [INFO] Beginning extraction
# INFO:pyppeteer.chromium_downloader:Beginning extraction
# [INFO] Chromium extracted to: /root/.local/share/pyppeteer/local-chromium/1181205
# INFO:pyppeteer.chromium_downloader:Chromium extracted to: /root/.local/share/pyppeteer/local-chromium/1181205

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# Set up the Selenium webdriver
driver = webdriver.Chrome()  # Replace with your preferred browser

# URL of the website to scrape
url = "https://homebase.map-dynamics.com/cmpx2024/marketplace/"

# Load the website
driver.get(url)

# Wait for the page to load
time.sleep(5)  # You can adjust the sleep time based on your internet connection

# Get the HTML content
html = driver.page_source

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find all company cards on the page
company_cards = soup.find_all('div', class_='company-card')

# Create an empty list to store the extracted data
companies = []

# Loop through each company card
for card in company_cards:
    company = {}

    # Extract company name
    company_name = card.find('h3', class_='company-name').text.strip()
    company['name'] = company_name

    # Extract website
    website = card.find('a', class_='website')
    if website:
        company['website'] = website['href']
    else:
        company['website'] = 'Not available'

    # Extract phone number
    phone = card.find('span', class_='phone')
    if phone:
        company['phone'] = phone.text.strip()
    else:
        company['phone'] = 'Not available'

    # Extract address
    address = card.find('span', class_='address')
    if address:
        company['address'] = address.text.strip()
    else:
        company['address'] = 'Not available'

    # Extract social media links
    social_media = card.find_all('a', class_='social-media')
    company['facebook'] = 'Not available'
    company['twitter'] = 'Not available'
    company['instagram'] = 'Not available'
    for link in social_media:
        if 'facebook' in link['href']:
            company['facebook'] = link['href']
        elif 'twitter' in link['href']:
            company['twitter'] = link['href']
        elif 'instagram' in link['href']:
            company['instagram'] = link['href']

    # Add company to the list
    companies.append(company)

# Print the extracted data
for company in companies:
    print(f"Company: {company['name']}")
    print(f"Website: {company['website']}")
    print(f"Phone: {company['phone']}")
    print(f"Address: {company['address']}")
    print(f"Facebook: {company['facebook']}")
    print(f"Twitter: {company['twitter']}")
    print(f"Instagram: {company['instagram']}")
    print("---")

# Close the Selenium webdriver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-24-1200c061e8ae> in <cell line: 6>()
#       4
#       5 # Set up the Selenium webdriver
# ----> 6 driver = webdriver.Chrome()  # Replace with your preferred browser
#       7
#       8 # URL of the website to scrape
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      64
#      65         try:
# ...
